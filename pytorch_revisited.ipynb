# %% [markdown]
# <a href="https://colab.research.google.com/github/HelloPenguin1/Pytorch_learning/blob/main/pytorch_revisited.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
a = [[1,2,3],
     [3,4,5]]
print(a)
# Out:
# [[1, 2, 3], [3, 4, 5]]
